# %% [markdown]
# <a href="https://colab.research.google.com/github/userantooun/invoice-extraction-agent/blob/main/invoice_extraction_agen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai pypdf
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.1/385.1 kB 5.3 MB/s eta 0:00:00

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ee0c4dec-f1e7-4a70-873e-ac5ad6913ad8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ee0c4dec-f1e7-4a70-873e-ac5ad6913ad8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pypdf import PdfReader

reader = PdfReader("sample_invoice.pdf")
text = ""
for page in reader.pages:
    text += page.extract_text()

print(text)
# Out:
# INVOICE
# Bright Supplies Co.
# 42 Industrial Ave, Beirut, Lebanon
# contact@brightsupplies.com
# Invoice #:
# Date:
# Due Date:
# INV-2024-0587
# 2024-03-12
# 2024-04-11
# Bill To:
# Cedar Tech Solutions
# 17 Hamra Street, Beirut, Lebanon
# Description
# Qty
# Unit Price
# Total
# Wireless Mouse
# 10
# $15.00
# $150.00
# USB-C Hub
# 5
# $25.00
# $125.00
# Laptop Stand
# 8
# $20.00
# $160.00
# HDMI Cable 2m
# 12
# $7.50
# $90.00
# Subtotal:
# $525.00
# Tax (11%):
# $57.75
# Total Due:
# $582.75
# Payment due within 30 days. Thank you for your business!

# %%
import os
from getpass import getpass
os.environ["GEMINI_API_KEY"] = getpass("Enter your Gemini API key: ")
# Out:
# Enter your Gemini API key: ··········
